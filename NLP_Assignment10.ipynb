# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 37.3 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
import gensim.downloader as api
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def preprocess(text):

    tokens = word_tokenize(text.lower())

    return [word for word in tokens if word.isalpha()]

# %%
def get_average_embedding(sentence, model):
    tokens = preprocess(sentence)
    word_vectors = []


    for word in tokens:
        if word in model:
            word_vectors.append(model[word])

    if len(word_vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(word_vectors, axis=0)

# %%
def semantic_search_glove_variant():
    print("--- Semantic Search using GloVe (Variant) ---")

    import gensim.downloader as api
    from sklearn.metrics.pairwise import cosine_similarity
    import numpy as np

    model = api.load("glove-wiki-gigaword-50")

    corpus = [
        "Latest smartphones with advanced features",
        "Benefits of regular exercise and fitness",
        "Cloud computing services for businesses",
        "Delicious Italian pasta recipes",
        "Machine learning applications in healthcare"
    ]

    query = "best mobile phone"

    def avg_embedding(text):
        words = text.split()
        vectors = [model[w] for w in words if w in model]
        return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

    corpus_vectors = [avg_embedding(sentence) for sentence in corpus]
    query_vector = avg_embedding(query).reshape(1, -1)

    similarity_scores = []
    for i in range(len(corpus)):
        score = cosine_similarity(query_vector, corpus_vectors[i].reshape(1, -1))[0][0]
        similarity_scores.append((corpus[i], score))

    ranked = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

    print("Query:", query)
    print("\nResults:")
    for sentence, score in ranked:
        print(f"{sentence} -> {score:.4f}")

    print("\nTop Match:", ranked[0][0])

# %%
semantic_search_glove_variant()
# Out:
# --- Semantic Search using GloVe (Variant) ---
# Query: best mobile phone
#
# Results:
# Latest smartphones with advanced features -> 0.8357
# Cloud computing services for businesses -> 0.8195
# Machine learning applications in healthcare -> 0.7369
# Benefits of regular exercise and fitness -> 0.7150
# Delicious Italian pasta recipes -> 0.3305
#
# Top Match: Latest smartphones with advanced features
