# %%
  import nltk
  nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
corpus = [
    "The cat is sleeping on the mat.",
    "Dogs bark loudly.",
    "He plays football every weekend."
]

# %%
tokenized_sentences = []
for sentence in corpus:
    sentence=sentence.lower()
    tokens = nltk.word_tokenize(sentence)
    tokenized_sentences.append(tokens)

# %%
print("Tokenized Output:")
for i, tokens in enumerate(tokenized_sentences):
    print(f"Sentence {i+1} Tokens: {tokens}")
print()
# Out:
# Tokenized Output:
# Sentence 1 Tokens: ['the', 'cat', 'is', 'sleeping', 'on', 'the', 'mat', '.']
# Sentence 2 Tokens: ['dogs', 'bark', 'loudly', '.']
# Sentence 3 Tokens: ['he', 'plays', 'football', 'every', 'weekend', '.']

# %%
print("POS Tagging Output:")
for i, tokens in enumerate(tokenized_sentences):
    pos_tags = nltk.pos_tag(tokens)
    print(f"Sentence {i+1} POS Tags: {pos_tags}")
# Out:
# POS Tagging Output:
# Sentence 1 POS Tags: [('the', 'DT'), ('cat', 'NN'), ('is', 'VBZ'), ('sleeping', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('mat', 'NN'), ('.', '.')]
# Sentence 2 POS Tags: [('dogs', 'NNS'), ('bark', 'NN'), ('loudly', 'RB'), ('.', '.')]
# Sentence 3 POS Tags: [('he', 'PRP'), ('plays', 'VBZ'), ('football', 'NN'), ('every', 'DT'), ('weekend', 'NN'), ('.', '.')]

# %%
import spacy


nlp = spacy.load("en_core_web_sm")

# %%
corpus = [
    "The cat is sleeping on the mat.",
    "Dogs bark loudly.",
    "He plays football every weekend."
]

# %%
tokenized_sentences = []
for sentence in corpus:
    doc = nlp(sentence)
    tokens = [token.text for token in doc]
    tokenized_sentences.append(tokens)

# %%
print("Tokenized Output:")
for i, tokens in enumerate(tokenized_sentences):
    print(f"Sentence {i+1} Tokens: {tokens}")
print()
# Out:
# Tokenized Output:
# Sentence 1 Tokens: ['The', 'cat', 'is', 'sleeping', 'on', 'the', 'mat', '.']
# Sentence 2 Tokens: ['Dogs', 'bark', 'loudly', '.']
# Sentence 3 Tokens: ['He', 'plays', 'football', 'every', 'weekend', '.']

# %%
print("POS Tagging Output:")
for i, sentence in enumerate(corpus):
    doc = nlp(sentence)
    pos_tags = [(token.text, token.pos_) for token in doc]
    print(f"Sentence {i+1} POS Tags: {pos_tags}")
# Out:
# POS Tagging Output:
# Sentence 1 POS Tags: [('The', 'DET'), ('cat', 'NOUN'), ('is', 'AUX'), ('sleeping', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('mat', 'NOUN'), ('.', 'PUNCT')]
# Sentence 2 POS Tags: [('Dogs', 'PROPN'), ('bark', 'NOUN'), ('loudly', 'ADV'), ('.', 'PUNCT')]
# Sentence 3 POS Tags: [('He', 'PRON'), ('plays', 'VERB'), ('football', 'NOUN'), ('every', 'DET'), ('weekend', 'NOUN'), ('.', 'PUNCT')]
